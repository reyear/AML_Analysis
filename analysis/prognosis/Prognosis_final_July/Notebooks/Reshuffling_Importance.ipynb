# %%
df <- read.table("../Reshuffling/gen_cyto_reshuffle_importance.tsv",sep="\t",header=T)
df$Ratio <- df$ref_CI/df$permuted_CI
#df[order(df$Ratio,decreasing=T),]
library(ggplot2)
source("../../../../src/tools.R")
set_notebook_plot_size(50,10)
ggplot(df,aes(x=reorder(feature,-Ratio,median),y=Ratio)) + geom_boxplot(aes(fill = reorder(feature,-Ratio,median)), notch=F)+theme(plot.title = element_text( size=45, face="bold.italic",hjust=0.5),legend.position="none",axis.text.x = element_text(angle = 90, hjust = 0.8,vjust=0.8,size=18),axis.text.y=element_text(size=28),axis.title.y = element_text(size = 20),axis.title.x = element_text(size = 20))+xlab("Selected Features") +
ggtitle("Feature Importance Reshuffling (Ratio of reference C-I over reshuffle C-I 100 times by feature)")
# Out:
# plot without title

# %%
df1 <- read.table("../Reshuffling/eln_comp.tsv")
df1$Ratio <- df1$ref_CI/df1$permuted_CI
ggplot(df1,aes(x=reorder(feature,-Ratio,median),y=Ratio)) + geom_boxplot(aes(fill = reorder(feature,-Ratio,median)), notch=F)+theme(plot.title = element_text( size=45, face="bold.italic",hjust=0.5),legend.position="none",axis.text.x = element_text(angle = 90, hjust = 0.8,vjust=0.8,size=18),axis.text.y=element_text(size=28),axis.title.y = element_text(size = 20),axis.title.x = element_text(size = 20))+xlab("Selected Features") +
ggtitle("Feature Importance Reshuffling (Ratio of reference C-I over reshuffle C-I 100 times by feature)")
# Out:
# Warning message in file(file, "rt"):
# “cannot open file '../Reshuffling/eln_comp.tsv': No such file or directory”
# Error in file(file, "rt"): cannot open the connection
# Traceback:
#
# 1. read.table("../Reshuffling/eln_comp.tsv")
# 2. file(file, "rt")

# %%
for (l in list.files("../Reshuffling/")){
    if(grepl("cyto",l)){
        print (l)
    }
}
# Out:
# [1] "comp_cyto_reshuffle_importance.tsv"
# [1] "comp_gen_cyto_clin_demo_reshuffle_importance.tsv"
# [1] "comp_gen_cyto_reshuffle_importance.tsv"
# [1] "cyto_age_reshuffle_importance.tsv"
# [1] "cyto_clin_demo_reshuffle_importance.tsv"
# [1] "cyto_clin_reshuffle_importance.tsv"
# [1] "cyto_demo_reshuffle_importance.tsv"
# [1] "cyto_gen_demo_reshuffle_importance.tsv"
# [1] "cyto_reshuffle_importance.tsv"
# [1] "eln_age_cyto_reshuffle_importance.tsv"
# [1] "eln_age_gen_cyto_reshuffle_importance.tsv"
# [1] "eln_comp_age_cyto_reshuffle_importance.tsv"
# [1] "eln_comp_age_gen_cyto_reshuffle_importance.tsv"
# [1] "eln_comp_cyto_clin_reshuffle_importance.tsv"
# [1] "eln_comp_cyto_demo_reshuffle_importance.tsv"
# [1] "eln_comp_cyto_demo_without_age_reshuffle_importance.tsv"
# [1] "eln_comp_cyto_reshuffle_importance.tsv"
# [1] "eln_comp_gen_cyto_reshuffle_importance.tsv"
# [1] "eln_cyto_clin_reshuffle_importance.tsv"
# [1] "eln_cyto_demo_reshuffle_importance.tsv"
# [1] "eln_cyto_demo_without_age_reshuffle_importance.tsv"
# [1] "eln_cyto_reshuffle_importance.tsv"
# [1] "eln_gen_cyto_reshuffle_importance.tsv"
# [1] "gen_cyto_clin_demo_reshuffle_importance.tsv"
# [1] "gen_cyto_reshuffle_importance.tsv"

# %%
df2 <- df[df$model=="eln_comp",]
ggplot(df2,aes(x=reorder(feature,-Ratio,median),y=Ratio)) + geom_boxplot(aes(fill = reorder(feature,-Ratio,median)), notch=F)+theme(plot.title = element_text( size=45, face="bold.italic",hjust=0.5),legend.position="none",axis.text.x = element_text(angle = 90, hjust = 0.8,vjust=0.8,size=18),axis.text.y=element_text(size=28),axis.title.y = element_text(size = 20),axis.title.x = element_text(size = 20))+xlab("Selected Features") +
ggtitle("Feature Importance Reshuffling (Ratio of reference C-I over reshuffle C-I 100 times by feature)")
# Out:
# plot without title
