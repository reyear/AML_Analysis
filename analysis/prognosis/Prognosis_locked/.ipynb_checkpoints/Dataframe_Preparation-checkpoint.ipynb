# %%
library(dummies)
correlates <- c("ahd","perf_status","bm_blasts","secondary","wbc","hb","plt","gender","age","os","os_status")

df_all_components <- read.table("../../clustering/Clustering_Final_Analysis/df_final_with_components.tsv")
df_initial <- read.table("../../../data/initial_dataset/Master_04_10_2019.csv",sep = ',' , header = T)
rownames(df_initial) <- df_initial$data_pd
df_initial <- df_initial[,-1:-4]
df_eln <- read.table("../../../data/updated_dataset/eln_ratio.tsv",sep = '\t' , header = T)
rownames(df_eln) <- df_eln$X
df_eln <- df_eln[-1]
df <- merge(df_eln,df_all_components,by=0)
rownames(df) <- df$Row.names
df <- df[-1]
df <- merge(df,df_initial[,correlates],by=0)
rownames(df) <- df$Row.names
df <- df[-1]
df <-df[,c(1:155,157:167)] 
df <- na.omit(df)
df <- df[df$os>0,]
df$eln_2017_ratio <- ifelse(df$eln_2017_ratio=="adverse",1,
                   ifelse(df$eln_2017_ratio=="intermediate",2,3))
df<- cbind(df,dummy('final_component',df, sep = "_"))
df <- df[,c(1:154,156:164,167:181,165:166)]
write.table(df,"data_frame_final_prognosis.tsv")

# %%
df_eln <- read.table("../../../data/updated_dataset/eln_ratio.tsv",sep = '\t' , header = T)

# %%
df_eln
# Out:
#      X        eln_2017_ratio
# 1    PD14868a favorable
# 2    PD14869c intermediate
# 3    PD14871a favorable
# 4    PD14872a adverse
# 5    PD14873a adverse
# 6    PD14874a adverse
# 7    PD14875a favorable
# 8    PD14876c adverse
# 9    PD14877c favorable
# 10   PD14879a adverse
# 11   PD14880c adverse
# 12   PD14881a intermediate
# 13   PD14882c intermediate
# 14   PD14883a adverse
# 15   PD14884a intermediate
# 16   PD14885a adverse
# 17   PD14888a adverse
# 18   PD14892c intermediate
# 19   PD14893c adverse
# 20   PD14895a adverse
# 21   PD14898c intermediate
# 22   PD14900a adverse
# 23   PD14902a favorable
# 24   PD14903a intermediate
# 25   PD14904c adverse
# 26   PD14905a intermediate
# 27   PD14908a adverse
# 28   PD14909c adverse
# 29   PD14910a favorable
# 30   PD14911a adverse
# ⋮    ⋮        ⋮
# 2065 PD25595a favorable
# 2066 PD25596a favorable
# 2067 PD25597a favorable
# 2068 PD25598c favorable
# 2069 PD25599a adverse
# 2070 PD25601c adverse
# 2071 PD25602a adverse
# 2072 PD25604c intermediate
# 2073 PD25606c intermediate
# 2074 PD25607c adverse
# 2075 PD25608a favorable
# 2076 PD25609c favorable
# 2077 PD25610c favorable
# 2078 PD25611a adverse
# 2079 PD25612c favorable
# 2080 PD25613a favorable
# 2081 PD25614c favorable
# 2082 PD25615a adverse
# 2083 PD25616a adverse
# 2084 PD25617a adverse
# 2085 PD25618c favorable
# 2086 PD25620c favorable
# 2087 PD25621a favorable
# 2088 PD25622a adverse
# 2089 PD25623a favorable
# 2090 PD25624c adverse
# 2091 PD25625a adverse
# 2092 PD25626c adverse
# 2093 PD25627a adverse
# 2094 PD25629c adverse
