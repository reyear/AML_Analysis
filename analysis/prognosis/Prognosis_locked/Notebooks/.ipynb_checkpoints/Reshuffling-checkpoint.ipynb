# %%
df <- read.table("../Reshuffling/eln_comp_reshuffle_importance.tsv")
df$Ratio <- df$ref_CI/df$permuted_CI
df <- df[df$algo=="RFS",]
library(dplyr)
df[order(df$Ratio,decreasing=T),] %>% group_by(feature)
# Out:
# Attaching package: ‘dplyr’
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#      feature                              ref_CI    permuted_CI algo model
# 8394 full_component_TP53_complex          0.6516914 0.5970748   RFS  eln_comp
# 9996 full_component_TP53_complex          0.6477361 0.5966641   RFS  eln_comp
# 9834 full_component_TP53_complex          0.6134203 0.5665338   RFS  eln_comp
# 8635 full_component_TP53_complex          0.6439216 0.5964115   RFS  eln_comp
# 8672 full_component_chr_splicing_multiple 0.6770460 0.6271226   RFS  eln_comp
# 9552 full_component_chr_splicing_multiple 0.6217229 0.5784855   RFS  eln_comp
# 8832 full_component_chr_splicing_multiple 0.6409203 0.5967162   RFS  eln_comp
# 8393 full_component_TP53_complex          0.6516914 0.6075032   RFS  eln_comp
# ...
