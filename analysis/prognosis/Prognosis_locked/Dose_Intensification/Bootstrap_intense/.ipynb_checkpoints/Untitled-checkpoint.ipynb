# %%
library('ggplot2')
library('reshape2')
library('ggpubr')
library(glmnet)
library(doMC)
library(survival)
library(data.table)
library(mltools)
library(CoxBoost)
library(randomForestSRC)
library(Hmisc)
library(gridExtra)
library("survminer")
library(dplyr)
library(broom)
library(tidyr)
source("../../../../../src/tools.R")
source('../../../tools_prognosis/run_prognosis.R')




### Features that we can use
###-----------------------------------------------------------------------------
df_final <- read.table("../../../../clustering/clustering_Final_1/df_final_full_component_ITD.tsv")
master <- read.table("../../../../../data/initial_dataset/Master_04_10_2019.tsv")
rownames(master) <- master$data_pd
df_final <- merge(df_final,master[,c("data_pd","intense")],by=0)
rownames(df_final) <- df_final$Row.names
df_final <- df_final[-1]
df_final$data_pd <- NULL

#Usual Features
eln <- c(2,3,4)
comp <- c(170:193)
age <- c(167)
intense <- c(196)

all_gen <- c(5:88)
vect <- apply(X=df_final[,all_gen],2,FUN=function(x) 100*length(which(x==1))/dim(df_final)[1])
gen <- match(names(vect[vect>=2]),names(df_final))
gen_without <- setdiff(gen,grep("^NPM1$", colnames(df_final)))
gen_without <- setdiff(gen_without,grep("^CEBPA_bi$", colnames(df_final))) 

all_cyto <- c(89:158)
vect <- apply(X=df_final[,all_cyto],2,FUN=function(x) 100*length(which(x==1))/dim(df_final)[1])
cyto <- match(names(vect[vect>=2]),names(df_final))
cyto_without <- setdiff(cyto,grep("^inv_16$", colnames(df_final)))
cyto_without <- setdiff(cyto_without,grep("^t_8_21$", colnames(df_final)))      
cyto_without <- setdiff(cyto_without,grep("^t_v_11$", colnames(df_final))) 

clin <- c(159:165)
demo <- c(166:167)
demo_without_age <-c(166)

name_genes <- colnames(df_final[,gen])
name_cyto <- colnames(df_final[,cyto])
name_comp <- colnames(df_final[,comp])
name_eln <- colnames(df_final[,eln])
for (col in c(name_eln,name_genes,name_cyto,name_comp)){
df_final[,paste(col,"intense",sep="_")] <- df_final[,col]*df_final$intense
}    
#Features with intensification

eln_intense <- c(197:199)
comp_intense <- c(255:278) 
gen_intense <- c(200:234)    

gen_without_intense <- setdiff(gen_intense,grep("^NPM1_intense$", colnames(df_final)))
gen_without_intense <- setdiff(gen_without_intense,grep("^CEBPA_bi_intense$", colnames(df_final)))
cyto_intense <- c(235:254)
cyto_without_intense <- setdiff(cyto_intense,grep("^inv_16_intense$", colnames(df_final)))
cyto_without_intense <- setdiff(cyto_without_intense,grep("^t_8_21_intense$", colnames(df_final)))      
cyto_without_intense <- setdiff(cyto_without_intense,grep("^t_v_11_intense$", colnames(df_final))) 



### Models to try
comp_comp_intense <- c (comp, comp_intense)
gen_gen_intense <- c (gen, gen_intense)
cyto_cyto_intense <- c (cyto, cyto_intense)
gen_cyto_gen_intense_cyto_intense <- c(gen,cyto,gen_intense,cyto_intense)
comp_gen_cyto_comp_intense_gen_intense_cyto_intense <- c(comp,gen_without,cyto_without,comp_intense,gen_without_intense,cyto_without_intense)
gen_cyto_clin_demo_gen_intense_cyto_intense <- c(gen_cyto_gen_intense_cyto_intense,clin,demo)
comp_clin_demo_comp_intense <- c(comp_comp_intense,clin,demo)
comp_gen_cyto_clin_demo_comp_intense_gen_intense_cyto_intense <- c(comp_gen_cyto_comp_intense_gen_intense_cyto_intense,clin,demo)
eln_eln_intense <- c(eln,eln_intense)
eln_comp_eln_intense_comp_intense <- c(eln_eln_intense,comp_comp_intense)
eln_gen_cyto_eln_intense_gen_intense_cyto_intense <- c(eln_eln_intense,gen_cyto_gen_intense_cyto_intense)
eln_comp_gen_cyto_eln_intense_comp_intense_gen_intense_cyto_intense <- c(eln_eln_intense,comp_gen_cyto_comp_intense_gen_intense_cyto_intense)
eln_comp_gen_cyto_clin_demo_eln_intense_comp_intense_gen_intense_cyto_intense <- c(eln_comp_gen_cyto_eln_intense_comp_intense_gen_intense_cyto_intense,clin,demo)
comp_intense_gen_intense_cyto_intense <- c(comp_intense,gen_without_intense,cyto_without_intense)
eln_intense_comp_intense_gen_intense_cyto_intense_clin_demo <- c(eln_intense,comp_intense_gen_intense_cyto_intense,clin,demo)
comp_intense_gen_intense <- c(comp_intense,gen_without_intense)
comp_intense_cyto_intense <- c(comp_intense,cyto_without_intense)
eln_intense_gen_intense <- c(eln_intense,gen_intense)
eln_intense_cyto_intense <- c(eln_intense,cyto_intense)
eln_intense_gen_intense_cyto_intense <- c(eln_intense,gen_intense,cyto_intense)

prognosis_features<- list(comp_comp_intense=c(comp_comp_intense,intense))

bootstrapping <- function(features=all_features,x,y,n_exp=100,alpha=0.7,mc.cores=50,model="glm"){
    set.seed(17)
    res_bootstrap <- data.frame('feature' = character(),
                      'coef' = numeric())
    design=x[,features]
    n = nrow(design)
    folds <- list()

    for (i in seq(n_exp)) {
        folds[[i]] <- sample(1:n, 0.8 * n, replace = TRUE)
    }

    nexp = length(folds)
    print("Start Bootstrapping")
    rescv = mclapply(seq(nexp),
                   FUN=function(iexp) {
                       set.seed(17)
                       cat(".")
                       x_sampling = design[folds[[iexp]],]
                       y_sampling = y[folds[[iexp]],]
                       if (model=="glm"){
                           cvfit <- cv.glmnet(x_sampling, y_sampling, family = 'cox', alpha=alpha, nfolds = 20, grouped = TRUE)
                           tmp <- as.data.frame(as.matrix(coef(cvfit, s = "lambda.min")))
                       } else if (model=="boost"){
                           cvfit<-CoxBoost(time=y_sampling[,1],status=y_sampling[,2],x=x_sampling)
                           tmp <- as.data.frame(as.matrix(coefficients(cvfit)))
                       } else if (model=="rfx"){
                           cvfit<-CoxRFX(data.frame(x_sampling),Surv(time=y_sampling[,1],event=y_sampling[,2]) , max.iter =50,tol=1e-3)
                           tmp <- as.data.frame(as.matrix(coef(cvfit)))
                       } else if (model=="rfs"){
                           cvfit <- rfsrc(Surv(time, status) ~ ., data=data.frame(x_sampling,y_sampling), ntree=1050, importance="TRUE",nodesize=20)
                           tmp <- as.data.frame(as.matrix(cvfit$importance))
                       }
                       colnames(tmp) <- 'coef'
                       tmp <- rownames_to_column(tmp, var = 'feature')


                   },
                   mc.cores=50
                   )

    for(i in 1:length(rescv)){
        res_bootstrap <- rbind(res_bootstrap,rescv[[i]])
    }


    res_bootstrap <- res_bootstrap[res_bootstrap$coef != 0,]
    return (res_bootstrap)
    }
 
x <- data.matrix(df_final)
y <- data.matrix(df_final[,c("os","os_status")])

colnames(y) = c("time","status")
response=y
              

algos <-c("glm","rfs","boost","rfx")
alphas=c(0,0.7,1)
for (i in 1:length(prognosis_features)){
    for (algo in algos){
        if (algo=="glm"){
            for (alpha in alphas){
                print(alpha)
                print(algo)
                bootstrap <- bootstrapping(prognosis_features[[i]],x,y,10,alpha,30,algo)
                tmp_1 <- bootstrap  %>% group_by(feature) %>% summarise_all(sum)
                tmp_2 <- bootstrap  %>% group_by(feature) %>% count(feature)
                print(paste(paste(names(prognosis_features)[i],paste(algo,alpha,sep="_"),sep="_bootstrap_"),".tsv",sep=""))
                write.table(data.frame(merge(tmp_1,tmp_2,by='feature')),"TESTS.tsv",quote=F,sep='\t')
        }
    }
}

# %%
for (i in 1:length(prognosis_features)){
    print("BGKAENJKLBHFJNKE")
    print(colnames(df_final[,prognosis_features[[i]]]))
}
# Out:
# [1] "BGKAENJKLBHFJNKE"
#  [1] "full_component_t_15_17"
#  [2] "full_component_inv_16"
#  [3] "full_component_t_8_21"
#  [4] "full_component_t_8_21_ITD"
#  [5] "full_component_t_11"
#  [6] "full_component_t_6_9"
#  [7] "full_component_t_6_9_ITD"
#  [8] "full_component_inv_3"
#  [9] "full_component_additions"
# [10] "full_component_TP53_complex"
# [11] "full_component_NPM1"
# [12] "full_component_NPM1_ITD"
# [13] "full_component_CEBPA_bi"
# [14] "full_component_CEBPA_bi_ITD"
# [15] "full_component_DNMT3A_IDH1_2"
# [16] "full_component_DNMT3A_IDH1_2_ITD"
# [17] "full_component_WT1"
# [18] "full_component_WT1_ITD"
# [19] "full_component_chr_splicing_multiple"
# [20] "full_component_chr_splicing_1"
# [21] "full_component_not_assigned"
# [22] "full_component_not_assigned_ITD"
# [23] "full_component_no_events"
# [24] "overlap"
# [25] "full_component_t_15_17_intense"
# [26] "full_component_inv_16_intense"
# [27] "full_component_t_8_21_intense"
# [28] "full_component_t_8_21_ITD_intense"
# [29] "full_component_t_11_intense"
# [30] "full_component_t_6_9_intense"
# [31] "full_component_t_6_9_ITD_intense"
# [32] "full_component_inv_3_intense"
# [33] "full_component_additions_intense"
# [34] "full_component_TP53_complex_intense"
# [35] "full_component_NPM1_intense"
# [36] "full_component_NPM1_ITD_intense"
# [37] "full_component_CEBPA_bi_intense"
# [38] "full_component_CEBPA_bi_ITD_intense"
# [39] "full_component_DNMT3A_IDH1_2_intense"
# [40] "full_component_DNMT3A_IDH1_2_ITD_intense"
# [41] "full_component_WT1_intense"
# [42] "full_component_WT1_ITD_intense"
# [43] "full_component_chr_splicing_multiple_intense"
# [44] "full_component_chr_splicing_1_intense"
# [45] "full_component_not_assigned_intense"
# [46] "full_component_not_assigned_ITD_intense"
# [47] "full_component_no_events_intense"
# [48] "overlap_intense"
# [49] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "ASXL1"                 "BCOR"                  "CBL"
#  [4] "CEBPA_bi"              "CEBPA_mono"            "DNMT3A"
#  [7] "EZH2"                  "ITD"                   "FLT3_TKD"
# [10] "FLT3_other"            "GATA2"                 "IDH1"
# [13] "IDH2_p.R140"           "IDH2_p.R172"           "KIT"
# [16] "KRAS"                  "MLL"                   "MYC"
# [19] "NF1"                   "NPM1"                  "NRAS_p.G12_13"
# [22] "NRAS_p.Q61_62"         "PHF6"                  "PTPN11"
# [25] "RAD21"                 "RUNX1"                 "SF3B1"
# [28] "SMC1A"                 "SMC3"                  "SRSF2"
# [31] "STAG2"                 "TET2"                  "TP53"
# [34] "U2AF1_p.S34"           "WT1"                   "ASXL1_intense"
# [37] "BCOR_intense"          "CBL_intense"           "CEBPA_bi_intense"
# [40] "CEBPA_mono_intense"    "DNMT3A_intense"        "EZH2_intense"
# [43] "ITD_intense"           "FLT3_TKD_intense"      "FLT3_other_intense"
# [46] "GATA2_intense"         "IDH1_intense"          "IDH2_p.R140_intense"
# [49] "IDH2_p.R172_intense"   "KIT_intense"           "KRAS_intense"
# [52] "MLL_intense"           "MYC_intense"           "NF1_intense"
# [55] "NPM1_intense"          "NRAS_p.G12_13_intense" "NRAS_p.Q61_62_intense"
# [58] "PHF6_intense"          "PTPN11_intense"        "RAD21_intense"
# [61] "RUNX1_intense"         "SF3B1_intense"         "SMC1A_intense"
# [64] "SMC3_intense"          "SRSF2_intense"         "STAG2_intense"
# [67] "TET2_intense"          "TP53_intense"          "U2AF1_p.S34_intense"
# [70] "WT1_intense"           "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "add_8"                   "add_11"
#  [3] "add_13"                  "add_21"
#  [5] "add_22"                  "del_20"
#  [7] "del_3"                   "del_5"
#  [9] "del_7"                   "del_9"
# [11] "del_12"                  "del_16"
# [13] "del_17"                  "del_18"
# [15] "minusy"                  "t_v_11"
# [17] "t_8_21"                  "complex"
# [19] "others_transloc"         "inv_16"
# [21] "add_8_intense"           "add_11_intense"
# [23] "add_13_intense"          "add_21_intense"
# [25] "add_22_intense"          "del_20_intense"
# [27] "del_3_intense"           "del_5_intense"
# [29] "del_7_intense"           "del_9_intense"
# [31] "del_12_intense"          "del_16_intense"
# [33] "del_17_intense"          "del_18_intense"
# [35] "minusy_intense"          "t_v_11_intense"
# [37] "t_8_21_intense"          "complex_intense"
# [39] "others_transloc_intense" "inv_16_intense"
# [41] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "ASXL1"                   "BCOR"
#   [3] "CBL"                     "CEBPA_bi"
#   [5] "CEBPA_mono"              "DNMT3A"
#   [7] "EZH2"                    "ITD"
#   [9] "FLT3_TKD"                "FLT3_other"
#  [11] "GATA2"                   "IDH1"
#  [13] "IDH2_p.R140"             "IDH2_p.R172"
#  [15] "KIT"                     "KRAS"
#  [17] "MLL"                     "MYC"
#  [19] "NF1"                     "NPM1"
#  [21] "NRAS_p.G12_13"           "NRAS_p.Q61_62"
#  [23] "PHF6"                    "PTPN11"
#  [25] "RAD21"                   "RUNX1"
#  [27] "SF3B1"                   "SMC1A"
#  [29] "SMC3"                    "SRSF2"
#  [31] "STAG2"                   "TET2"
#  [33] "TP53"                    "U2AF1_p.S34"
#  [35] "WT1"                     "add_8"
#  [37] "add_11"                  "add_13"
#  [39] "add_21"                  "add_22"
#  [41] "del_20"                  "del_3"
#  [43] "del_5"                   "del_7"
#  [45] "del_9"                   "del_12"
#  [47] "del_16"                  "del_17"
#  [49] "del_18"                  "minusy"
#  [51] "t_v_11"                  "t_8_21"
#  [53] "complex"                 "others_transloc"
#  [55] "inv_16"                  "ASXL1_intense"
#  [57] "BCOR_intense"            "CBL_intense"
#  [59] "CEBPA_bi_intense"        "CEBPA_mono_intense"
#  [61] "DNMT3A_intense"          "EZH2_intense"
#  [63] "ITD_intense"             "FLT3_TKD_intense"
#  [65] "FLT3_other_intense"      "GATA2_intense"
#  [67] "IDH1_intense"            "IDH2_p.R140_intense"
#  [69] "IDH2_p.R172_intense"     "KIT_intense"
#  [71] "KRAS_intense"            "MLL_intense"
#  [73] "MYC_intense"             "NF1_intense"
#  [75] "NPM1_intense"            "NRAS_p.G12_13_intense"
#  [77] "NRAS_p.Q61_62_intense"   "PHF6_intense"
#  [79] "PTPN11_intense"          "RAD21_intense"
#  [81] "RUNX1_intense"           "SF3B1_intense"
#  [83] "SMC1A_intense"           "SMC3_intense"
#  [85] "SRSF2_intense"           "STAG2_intense"
#  [87] "TET2_intense"            "TP53_intense"
#  [89] "U2AF1_p.S34_intense"     "WT1_intense"
#  [91] "add_8_intense"           "add_11_intense"
#  [93] "add_13_intense"          "add_21_intense"
#  [95] "add_22_intense"          "del_20_intense"
#  [97] "del_3_intense"           "del_5_intense"
#  [99] "del_7_intense"           "del_9_intense"
# [101] "del_12_intense"          "del_16_intense"
# [103] "del_17_intense"          "del_18_intense"
# [105] "minusy_intense"          "t_v_11_intense"
# [107] "t_8_21_intense"          "complex_intense"
# [109] "others_transloc_intense" "inv_16_intense"
# [111] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "full_component_t_15_17"
#   [2] "full_component_inv_16"
#   [3] "full_component_t_8_21"
#   [4] "full_component_t_8_21_ITD"
#   [5] "full_component_t_11"
#   [6] "full_component_t_6_9"
#   [7] "full_component_t_6_9_ITD"
#   [8] "full_component_inv_3"
#   [9] "full_component_additions"
#  [10] "full_component_TP53_complex"
#  [11] "full_component_NPM1"
#  [12] "full_component_NPM1_ITD"
#  [13] "full_component_CEBPA_bi"
#  [14] "full_component_CEBPA_bi_ITD"
#  [15] "full_component_DNMT3A_IDH1_2"
#  [16] "full_component_DNMT3A_IDH1_2_ITD"
#  [17] "full_component_WT1"
#  [18] "full_component_WT1_ITD"
#  [19] "full_component_chr_splicing_multiple"
#  [20] "full_component_chr_splicing_1"
#  [21] "full_component_not_assigned"
#  [22] "full_component_not_assigned_ITD"
#  [23] "full_component_no_events"
#  [24] "overlap"
#  [25] "ASXL1"
#  [26] "BCOR"
#  [27] "CBL"
#  [28] "CEBPA_mono"
#  [29] "DNMT3A"
#  [30] "EZH2"
#  [31] "ITD"
#  [32] "FLT3_TKD"
#  [33] "FLT3_other"
#  [34] "GATA2"
#  [35] "IDH1"
#  [36] "IDH2_p.R140"
#  [37] "IDH2_p.R172"
#  [38] "KIT"
#  [39] "KRAS"
#  [40] "MLL"
#  [41] "MYC"
#  [42] "NF1"
#  [43] "NRAS_p.G12_13"
#  [44] "NRAS_p.Q61_62"
#  [45] "PHF6"
#  [46] "PTPN11"
#  [47] "RAD21"
#  [48] "RUNX1"
#  [49] "SF3B1"
#  [50] "SMC1A"
#  [51] "SMC3"
#  [52] "SRSF2"
#  [53] "STAG2"
#  [54] "TET2"
#  [55] "TP53"
#  [56] "U2AF1_p.S34"
#  [57] "WT1"
#  [58] "add_8"
#  [59] "add_11"
#  [60] "add_13"
#  [61] "add_21"
#  [62] "add_22"
#  [63] "del_20"
#  [64] "del_3"
#  [65] "del_5"
#  [66] "del_7"
#  [67] "del_9"
#  [68] "del_12"
#  [69] "del_16"
#  [70] "del_17"
#  [71] "del_18"
#  [72] "minusy"
#  [73] "complex"
#  [74] "others_transloc"
#  [75] "full_component_t_15_17_intense"
#  [76] "full_component_inv_16_intense"
#  [77] "full_component_t_8_21_intense"
#  [78] "full_component_t_8_21_ITD_intense"
#  [79] "full_component_t_11_intense"
#  [80] "full_component_t_6_9_intense"
#  [81] "full_component_t_6_9_ITD_intense"
#  [82] "full_component_inv_3_intense"
#  [83] "full_component_additions_intense"
#  [84] "full_component_TP53_complex_intense"
#  [85] "full_component_NPM1_intense"
#  [86] "full_component_NPM1_ITD_intense"
#  [87] "full_component_CEBPA_bi_intense"
#  [88] "full_component_CEBPA_bi_ITD_intense"
#  [89] "full_component_DNMT3A_IDH1_2_intense"
#  [90] "full_component_DNMT3A_IDH1_2_ITD_intense"
#  [91] "full_component_WT1_intense"
#  [92] "full_component_WT1_ITD_intense"
#  [93] "full_component_chr_splicing_multiple_intense"
#  [94] "full_component_chr_splicing_1_intense"
#  [95] "full_component_not_assigned_intense"
#  [96] "full_component_not_assigned_ITD_intense"
#  [97] "full_component_no_events_intense"
#  [98] "overlap_intense"
#  [99] "ASXL1_intense"
# [100] "BCOR_intense"
# [101] "CBL_intense"
# [102] "CEBPA_mono_intense"
# [103] "DNMT3A_intense"
# [104] "EZH2_intense"
# [105] "ITD_intense"
# [106] "FLT3_TKD_intense"
# [107] "FLT3_other_intense"
# [108] "GATA2_intense"
# [109] "IDH1_intense"
# [110] "IDH2_p.R140_intense"
# [111] "IDH2_p.R172_intense"
# [112] "KIT_intense"
# [113] "KRAS_intense"
# [114] "MLL_intense"
# [115] "MYC_intense"
# [116] "NF1_intense"
# [117] "NRAS_p.G12_13_intense"
# [118] "NRAS_p.Q61_62_intense"
# [119] "PHF6_intense"
# [120] "PTPN11_intense"
# [121] "RAD21_intense"
# [122] "RUNX1_intense"
# [123] "SF3B1_intense"
# [124] "SMC1A_intense"
# [125] "SMC3_intense"
# [126] "SRSF2_intense"
# [127] "STAG2_intense"
# [128] "TET2_intense"
# [129] "TP53_intense"
# [130] "U2AF1_p.S34_intense"
# [131] "WT1_intense"
# [132] "add_8_intense"
# [133] "add_11_intense"
# [134] "add_13_intense"
# [135] "add_21_intense"
# [136] "add_22_intense"
# [137] "del_20_intense"
# [138] "del_3_intense"
# [139] "del_5_intense"
# [140] "del_7_intense"
# [141] "del_9_intense"
# [142] "del_12_intense"
# [143] "del_16_intense"
# [144] "del_17_intense"
# [145] "del_18_intense"
# [146] "minusy_intense"
# [147] "complex_intense"
# [148] "others_transloc_intense"
# [149] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "ASXL1"                   "BCOR"
#   [3] "CBL"                     "CEBPA_bi"
#   [5] "CEBPA_mono"              "DNMT3A"
#   [7] "EZH2"                    "ITD"
#   [9] "FLT3_TKD"                "FLT3_other"
#  [11] "GATA2"                   "IDH1"
#  [13] "IDH2_p.R140"             "IDH2_p.R172"
#  [15] "KIT"                     "KRAS"
#  [17] "MLL"                     "MYC"
#  [19] "NF1"                     "NPM1"
#  [21] "NRAS_p.G12_13"           "NRAS_p.Q61_62"
#  [23] "PHF6"                    "PTPN11"
#  [25] "RAD21"                   "RUNX1"
#  [27] "SF3B1"                   "SMC1A"
#  [29] "SMC3"                    "SRSF2"
#  [31] "STAG2"                   "TET2"
#  [33] "TP53"                    "U2AF1_p.S34"
#  [35] "WT1"                     "add_8"
#  [37] "add_11"                  "add_13"
#  [39] "add_21"                  "add_22"
#  [41] "del_20"                  "del_3"
#  [43] "del_5"                   "del_7"
#  [45] "del_9"                   "del_12"
#  [47] "del_16"                  "del_17"
#  [49] "del_18"                  "minusy"
#  [51] "t_v_11"                  "t_8_21"
#  [53] "complex"                 "others_transloc"
#  [55] "inv_16"                  "ASXL1_intense"
#  [57] "BCOR_intense"            "CBL_intense"
#  [59] "CEBPA_bi_intense"        "CEBPA_mono_intense"
#  [61] "DNMT3A_intense"          "EZH2_intense"
#  [63] "ITD_intense"             "FLT3_TKD_intense"
#  [65] "FLT3_other_intense"      "GATA2_intense"
#  [67] "IDH1_intense"            "IDH2_p.R140_intense"
#  [69] "IDH2_p.R172_intense"     "KIT_intense"
#  [71] "KRAS_intense"            "MLL_intense"
#  [73] "MYC_intense"             "NF1_intense"
#  [75] "NPM1_intense"            "NRAS_p.G12_13_intense"
#  [77] "NRAS_p.Q61_62_intense"   "PHF6_intense"
#  [79] "PTPN11_intense"          "RAD21_intense"
#  [81] "RUNX1_intense"           "SF3B1_intense"
#  [83] "SMC1A_intense"           "SMC3_intense"
#  [85] "SRSF2_intense"           "STAG2_intense"
#  [87] "TET2_intense"            "TP53_intense"
#  [89] "U2AF1_p.S34_intense"     "WT1_intense"
#  [91] "add_8_intense"           "add_11_intense"
#  [93] "add_13_intense"          "add_21_intense"
#  [95] "add_22_intense"          "del_20_intense"
#  [97] "del_3_intense"           "del_5_intense"
#  [99] "del_7_intense"           "del_9_intense"
# [101] "del_12_intense"          "del_16_intense"
# [103] "del_17_intense"          "del_18_intense"
# [105] "minusy_intense"          "t_v_11_intense"
# [107] "t_8_21_intense"          "complex_intense"
# [109] "others_transloc_intense" "inv_16_intense"
# [111] "ahd"                     "perf_status"
# [113] "bm_blasts"               "secondary"
# [115] "wbc"                     "hb"
# [117] "plt"                     "gender"
# [119] "age"                     "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "full_component_t_15_17"
#  [2] "full_component_inv_16"
#  [3] "full_component_t_8_21"
#  [4] "full_component_t_8_21_ITD"
#  [5] "full_component_t_11"
#  [6] "full_component_t_6_9"
#  [7] "full_component_t_6_9_ITD"
#  [8] "full_component_inv_3"
#  [9] "full_component_additions"
# [10] "full_component_TP53_complex"
# [11] "full_component_NPM1"
# [12] "full_component_NPM1_ITD"
# [13] "full_component_CEBPA_bi"
# [14] "full_component_CEBPA_bi_ITD"
# [15] "full_component_DNMT3A_IDH1_2"
# [16] "full_component_DNMT3A_IDH1_2_ITD"
# [17] "full_component_WT1"
# [18] "full_component_WT1_ITD"
# [19] "full_component_chr_splicing_multiple"
# [20] "full_component_chr_splicing_1"
# [21] "full_component_not_assigned"
# [22] "full_component_not_assigned_ITD"
# [23] "full_component_no_events"
# [24] "overlap"
# [25] "full_component_t_15_17_intense"
# [26] "full_component_inv_16_intense"
# [27] "full_component_t_8_21_intense"
# [28] "full_component_t_8_21_ITD_intense"
# [29] "full_component_t_11_intense"
# [30] "full_component_t_6_9_intense"
# [31] "full_component_t_6_9_ITD_intense"
# [32] "full_component_inv_3_intense"
# [33] "full_component_additions_intense"
# [34] "full_component_TP53_complex_intense"
# [35] "full_component_NPM1_intense"
# [36] "full_component_NPM1_ITD_intense"
# [37] "full_component_CEBPA_bi_intense"
# [38] "full_component_CEBPA_bi_ITD_intense"
# [39] "full_component_DNMT3A_IDH1_2_intense"
# [40] "full_component_DNMT3A_IDH1_2_ITD_intense"
# [41] "full_component_WT1_intense"
# [42] "full_component_WT1_ITD_intense"
# [43] "full_component_chr_splicing_multiple_intense"
# [44] "full_component_chr_splicing_1_intense"
# [45] "full_component_not_assigned_intense"
# [46] "full_component_not_assigned_ITD_intense"
# [47] "full_component_no_events_intense"
# [48] "overlap_intense"
# [49] "ahd"
# [50] "perf_status"
# [51] "bm_blasts"
# [52] "secondary"
# [53] "wbc"
# [54] "hb"
# [55] "plt"
# [56] "gender"
# [57] "age"
# [58] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "full_component_t_15_17"
#   [2] "full_component_inv_16"
#   [3] "full_component_t_8_21"
#   [4] "full_component_t_8_21_ITD"
#   [5] "full_component_t_11"
#   [6] "full_component_t_6_9"
#   [7] "full_component_t_6_9_ITD"
#   [8] "full_component_inv_3"
#   [9] "full_component_additions"
#  [10] "full_component_TP53_complex"
#  [11] "full_component_NPM1"
#  [12] "full_component_NPM1_ITD"
#  [13] "full_component_CEBPA_bi"
#  [14] "full_component_CEBPA_bi_ITD"
#  [15] "full_component_DNMT3A_IDH1_2"
#  [16] "full_component_DNMT3A_IDH1_2_ITD"
#  [17] "full_component_WT1"
#  [18] "full_component_WT1_ITD"
#  [19] "full_component_chr_splicing_multiple"
#  [20] "full_component_chr_splicing_1"
#  [21] "full_component_not_assigned"
#  [22] "full_component_not_assigned_ITD"
#  [23] "full_component_no_events"
#  [24] "overlap"
#  [25] "ASXL1"
#  [26] "BCOR"
#  [27] "CBL"
#  [28] "CEBPA_mono"
#  [29] "DNMT3A"
#  [30] "EZH2"
#  [31] "ITD"
#  [32] "FLT3_TKD"
#  [33] "FLT3_other"
#  [34] "GATA2"
#  [35] "IDH1"
#  [36] "IDH2_p.R140"
#  [37] "IDH2_p.R172"
#  [38] "KIT"
#  [39] "KRAS"
#  [40] "MLL"
#  [41] "MYC"
#  [42] "NF1"
#  [43] "NRAS_p.G12_13"
#  [44] "NRAS_p.Q61_62"
#  [45] "PHF6"
#  [46] "PTPN11"
#  [47] "RAD21"
#  [48] "RUNX1"
#  [49] "SF3B1"
#  [50] "SMC1A"
#  [51] "SMC3"
#  [52] "SRSF2"
#  [53] "STAG2"
#  [54] "TET2"
#  [55] "TP53"
#  [56] "U2AF1_p.S34"
#  [57] "WT1"
#  [58] "add_8"
#  [59] "add_11"
#  [60] "add_13"
#  [61] "add_21"
#  [62] "add_22"
#  [63] "del_20"
#  [64] "del_3"
#  [65] "del_5"
#  [66] "del_7"
#  [67] "del_9"
#  [68] "del_12"
#  [69] "del_16"
#  [70] "del_17"
#  [71] "del_18"
#  [72] "minusy"
#  [73] "complex"
#  [74] "others_transloc"
#  [75] "full_component_t_15_17_intense"
#  [76] "full_component_inv_16_intense"
#  [77] "full_component_t_8_21_intense"
#  [78] "full_component_t_8_21_ITD_intense"
#  [79] "full_component_t_11_intense"
#  [80] "full_component_t_6_9_intense"
#  [81] "full_component_t_6_9_ITD_intense"
#  [82] "full_component_inv_3_intense"
#  [83] "full_component_additions_intense"
#  [84] "full_component_TP53_complex_intense"
#  [85] "full_component_NPM1_intense"
#  [86] "full_component_NPM1_ITD_intense"
#  [87] "full_component_CEBPA_bi_intense"
#  [88] "full_component_CEBPA_bi_ITD_intense"
#  [89] "full_component_DNMT3A_IDH1_2_intense"
#  [90] "full_component_DNMT3A_IDH1_2_ITD_intense"
#  [91] "full_component_WT1_intense"
#  [92] "full_component_WT1_ITD_intense"
#  [93] "full_component_chr_splicing_multiple_intense"
#  [94] "full_component_chr_splicing_1_intense"
#  [95] "full_component_not_assigned_intense"
#  [96] "full_component_not_assigned_ITD_intense"
#  [97] "full_component_no_events_intense"
#  [98] "overlap_intense"
#  [99] "ASXL1_intense"
# [100] "BCOR_intense"
# [101] "CBL_intense"
# [102] "CEBPA_mono_intense"
# [103] "DNMT3A_intense"
# [104] "EZH2_intense"
# [105] "ITD_intense"
# [106] "FLT3_TKD_intense"
# [107] "FLT3_other_intense"
# [108] "GATA2_intense"
# [109] "IDH1_intense"
# [110] "IDH2_p.R140_intense"
# [111] "IDH2_p.R172_intense"
# [112] "KIT_intense"
# [113] "KRAS_intense"
# [114] "MLL_intense"
# [115] "MYC_intense"
# [116] "NF1_intense"
# [117] "NRAS_p.G12_13_intense"
# [118] "NRAS_p.Q61_62_intense"
# [119] "PHF6_intense"
# [120] "PTPN11_intense"
# [121] "RAD21_intense"
# [122] "RUNX1_intense"
# [123] "SF3B1_intense"
# [124] "SMC1A_intense"
# [125] "SMC3_intense"
# [126] "SRSF2_intense"
# [127] "STAG2_intense"
# [128] "TET2_intense"
# [129] "TP53_intense"
# [130] "U2AF1_p.S34_intense"
# [131] "WT1_intense"
# [132] "add_8_intense"
# [133] "add_11_intense"
# [134] "add_13_intense"
# [135] "add_21_intense"
# [136] "add_22_intense"
# [137] "del_20_intense"
# [138] "del_3_intense"
# [139] "del_5_intense"
# [140] "del_7_intense"
# [141] "del_9_intense"
# [142] "del_12_intense"
# [143] "del_16_intense"
# [144] "del_17_intense"
# [145] "del_18_intense"
# [146] "minusy_intense"
# [147] "complex_intense"
# [148] "others_transloc_intense"
# [149] "ahd"
# [150] "perf_status"
# [151] "bm_blasts"
# [152] "secondary"
# [153] "wbc"
# [154] "hb"
# [155] "plt"
# [156] "gender"
# [157] "age"
# [158] "intense"
# [1] "BGKAENJKLBHFJNKE"
# [1] "eln_2017_adverse"              "eln_2017_favorable"
# [3] "eln_2017_intermediate"         "eln_2017_adverse_intense"
# [5] "eln_2017_favorable_intense"    "eln_2017_intermediate_intense"
# [7] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "eln_2017_adverse"
#  [2] "eln_2017_favorable"
#  [3] "eln_2017_intermediate"
#  [4] "eln_2017_adverse_intense"
#  [5] "eln_2017_favorable_intense"
#  [6] "eln_2017_intermediate_intense"
#  [7] "full_component_t_15_17"
#  [8] "full_component_inv_16"
#  [9] "full_component_t_8_21"
# [10] "full_component_t_8_21_ITD"
# [11] "full_component_t_11"
# [12] "full_component_t_6_9"
# [13] "full_component_t_6_9_ITD"
# [14] "full_component_inv_3"
# [15] "full_component_additions"
# [16] "full_component_TP53_complex"
# [17] "full_component_NPM1"
# [18] "full_component_NPM1_ITD"
# [19] "full_component_CEBPA_bi"
# [20] "full_component_CEBPA_bi_ITD"
# [21] "full_component_DNMT3A_IDH1_2"
# [22] "full_component_DNMT3A_IDH1_2_ITD"
# [23] "full_component_WT1"
# [24] "full_component_WT1_ITD"
# [25] "full_component_chr_splicing_multiple"
# [26] "full_component_chr_splicing_1"
# [27] "full_component_not_assigned"
# [28] "full_component_not_assigned_ITD"
# [29] "full_component_no_events"
# [30] "overlap"
# [31] "full_component_t_15_17_intense"
# [32] "full_component_inv_16_intense"
# [33] "full_component_t_8_21_intense"
# [34] "full_component_t_8_21_ITD_intense"
# [35] "full_component_t_11_intense"
# [36] "full_component_t_6_9_intense"
# [37] "full_component_t_6_9_ITD_intense"
# [38] "full_component_inv_3_intense"
# [39] "full_component_additions_intense"
# [40] "full_component_TP53_complex_intense"
# [41] "full_component_NPM1_intense"
# [42] "full_component_NPM1_ITD_intense"
# [43] "full_component_CEBPA_bi_intense"
# [44] "full_component_CEBPA_bi_ITD_intense"
# [45] "full_component_DNMT3A_IDH1_2_intense"
# [46] "full_component_DNMT3A_IDH1_2_ITD_intense"
# [47] "full_component_WT1_intense"
# [48] "full_component_WT1_ITD_intense"
# [49] "full_component_chr_splicing_multiple_intense"
# [50] "full_component_chr_splicing_1_intense"
# [51] "full_component_not_assigned_intense"
# [52] "full_component_not_assigned_ITD_intense"
# [53] "full_component_no_events_intense"
# [54] "overlap_intense"
# [55] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "eln_2017_adverse"              "eln_2017_favorable"
#   [3] "eln_2017_intermediate"         "eln_2017_adverse_intense"
#   [5] "eln_2017_favorable_intense"    "eln_2017_intermediate_intense"
#   [7] "ASXL1"                         "BCOR"
#   [9] "CBL"                           "CEBPA_bi"
#  [11] "CEBPA_mono"                    "DNMT3A"
#  [13] "EZH2"                          "ITD"
#  [15] "FLT3_TKD"                      "FLT3_other"
#  [17] "GATA2"                         "IDH1"
#  [19] "IDH2_p.R140"                   "IDH2_p.R172"
#  [21] "KIT"                           "KRAS"
#  [23] "MLL"                           "MYC"
#  [25] "NF1"                           "NPM1"
#  [27] "NRAS_p.G12_13"                 "NRAS_p.Q61_62"
#  [29] "PHF6"                          "PTPN11"
#  [31] "RAD21"                         "RUNX1"
#  [33] "SF3B1"                         "SMC1A"
#  [35] "SMC3"                          "SRSF2"
#  [37] "STAG2"                         "TET2"
#  [39] "TP53"                          "U2AF1_p.S34"
#  [41] "WT1"                           "add_8"
#  [43] "add_11"                        "add_13"
#  [45] "add_21"                        "add_22"
#  [47] "del_20"                        "del_3"
#  [49] "del_5"                         "del_7"
#  [51] "del_9"                         "del_12"
#  [53] "del_16"                        "del_17"
#  [55] "del_18"                        "minusy"
#  [57] "t_v_11"                        "t_8_21"
#  [59] "complex"                       "others_transloc"
#  [61] "inv_16"                        "ASXL1_intense"
#  [63] "BCOR_intense"                  "CBL_intense"
#  [65] "CEBPA_bi_intense"              "CEBPA_mono_intense"
#  [67] "DNMT3A_intense"                "EZH2_intense"
#  [69] "ITD_intense"                   "FLT3_TKD_intense"
#  [71] "FLT3_other_intense"            "GATA2_intense"
#  [73] "IDH1_intense"                  "IDH2_p.R140_intense"
#  [75] "IDH2_p.R172_intense"           "KIT_intense"
#  [77] "KRAS_intense"                  "MLL_intense"
#  [79] "MYC_intense"                   "NF1_intense"
#  [81] "NPM1_intense"                  "NRAS_p.G12_13_intense"
#  [83] "NRAS_p.Q61_62_intense"         "PHF6_intense"
#  [85] "PTPN11_intense"                "RAD21_intense"
#  [87] "RUNX1_intense"                 "SF3B1_intense"
#  [89] "SMC1A_intense"                 "SMC3_intense"
#  [91] "SRSF2_intense"                 "STAG2_intense"
#  [93] "TET2_intense"                  "TP53_intense"
#  [95] "U2AF1_p.S34_intense"           "WT1_intense"
#  [97] "add_8_intense"                 "add_11_intense"
#  [99] "add_13_intense"                "add_21_intense"
# [101] "add_22_intense"                "del_20_intense"
# [103] "del_3_intense"                 "del_5_intense"
# [105] "del_7_intense"                 "del_9_intense"
# [107] "del_12_intense"                "del_16_intense"
# [109] "del_17_intense"                "del_18_intense"
# [111] "minusy_intense"                "t_v_11_intense"
# [113] "t_8_21_intense"                "complex_intense"
# [115] "others_transloc_intense"       "inv_16_intense"
# [117] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "eln_2017_adverse"
#   [2] "eln_2017_favorable"
#   [3] "eln_2017_intermediate"
#   [4] "eln_2017_adverse_intense"
#   [5] "eln_2017_favorable_intense"
#   [6] "eln_2017_intermediate_intense"
#   [7] "full_component_t_15_17"
#   [8] "full_component_inv_16"
#   [9] "full_component_t_8_21"
#  [10] "full_component_t_8_21_ITD"
#  [11] "full_component_t_11"
#  [12] "full_component_t_6_9"
#  [13] "full_component_t_6_9_ITD"
#  [14] "full_component_inv_3"
#  [15] "full_component_additions"
#  [16] "full_component_TP53_complex"
#  [17] "full_component_NPM1"
#  [18] "full_component_NPM1_ITD"
#  [19] "full_component_CEBPA_bi"
#  [20] "full_component_CEBPA_bi_ITD"
#  [21] "full_component_DNMT3A_IDH1_2"
#  [22] "full_component_DNMT3A_IDH1_2_ITD"
#  [23] "full_component_WT1"
#  [24] "full_component_WT1_ITD"
#  [25] "full_component_chr_splicing_multiple"
#  [26] "full_component_chr_splicing_1"
#  [27] "full_component_not_assigned"
#  [28] "full_component_not_assigned_ITD"
#  [29] "full_component_no_events"
#  [30] "overlap"
#  [31] "ASXL1"
#  [32] "BCOR"
#  [33] "CBL"
#  [34] "CEBPA_mono"
#  [35] "DNMT3A"
#  [36] "EZH2"
#  [37] "ITD"
#  [38] "FLT3_TKD"
#  [39] "FLT3_other"
#  [40] "GATA2"
#  [41] "IDH1"
#  [42] "IDH2_p.R140"
#  [43] "IDH2_p.R172"
#  [44] "KIT"
#  [45] "KRAS"
#  [46] "MLL"
#  [47] "MYC"
#  [48] "NF1"
#  [49] "NRAS_p.G12_13"
#  [50] "NRAS_p.Q61_62"
#  [51] "PHF6"
#  [52] "PTPN11"
#  [53] "RAD21"
#  [54] "RUNX1"
#  [55] "SF3B1"
#  [56] "SMC1A"
#  [57] "SMC3"
#  [58] "SRSF2"
#  [59] "STAG2"
#  [60] "TET2"
#  [61] "TP53"
#  [62] "U2AF1_p.S34"
#  [63] "WT1"
#  [64] "add_8"
#  [65] "add_11"
#  [66] "add_13"
#  [67] "add_21"
#  [68] "add_22"
#  [69] "del_20"
#  [70] "del_3"
#  [71] "del_5"
#  [72] "del_7"
#  [73] "del_9"
#  [74] "del_12"
#  [75] "del_16"
#  [76] "del_17"
#  [77] "del_18"
#  [78] "minusy"
#  [79] "complex"
#  [80] "others_transloc"
#  [81] "full_component_t_15_17_intense"
#  [82] "full_component_inv_16_intense"
#  [83] "full_component_t_8_21_intense"
#  [84] "full_component_t_8_21_ITD_intense"
#  [85] "full_component_t_11_intense"
#  [86] "full_component_t_6_9_intense"
#  [87] "full_component_t_6_9_ITD_intense"
#  [88] "full_component_inv_3_intense"
#  [89] "full_component_additions_intense"
#  [90] "full_component_TP53_complex_intense"
#  [91] "full_component_NPM1_intense"
#  [92] "full_component_NPM1_ITD_intense"
#  [93] "full_component_CEBPA_bi_intense"
#  [94] "full_component_CEBPA_bi_ITD_intense"
#  [95] "full_component_DNMT3A_IDH1_2_intense"
#  [96] "full_component_DNMT3A_IDH1_2_ITD_intense"
#  [97] "full_component_WT1_intense"
#  [98] "full_component_WT1_ITD_intense"
#  [99] "full_component_chr_splicing_multiple_intense"
# [100] "full_component_chr_splicing_1_intense"
# [101] "full_component_not_assigned_intense"
# [102] "full_component_not_assigned_ITD_intense"
# [103] "full_component_no_events_intense"
# [104] "overlap_intense"
# [105] "ASXL1_intense"
# [106] "BCOR_intense"
# [107] "CBL_intense"
# [108] "CEBPA_mono_intense"
# [109] "DNMT3A_intense"
# [110] "EZH2_intense"
# [111] "ITD_intense"
# [112] "FLT3_TKD_intense"
# [113] "FLT3_other_intense"
# [114] "GATA2_intense"
# [115] "IDH1_intense"
# [116] "IDH2_p.R140_intense"
# [117] "IDH2_p.R172_intense"
# [118] "KIT_intense"
# [119] "KRAS_intense"
# [120] "MLL_intense"
# [121] "MYC_intense"
# [122] "NF1_intense"
# [123] "NRAS_p.G12_13_intense"
# [124] "NRAS_p.Q61_62_intense"
# [125] "PHF6_intense"
# [126] "PTPN11_intense"
# [127] "RAD21_intense"
# [128] "RUNX1_intense"
# [129] "SF3B1_intense"
# [130] "SMC1A_intense"
# [131] "SMC3_intense"
# [132] "SRSF2_intense"
# [133] "STAG2_intense"
# [134] "TET2_intense"
# [135] "TP53_intense"
# [136] "U2AF1_p.S34_intense"
# [137] "WT1_intense"
# [138] "add_8_intense"
# [139] "add_11_intense"
# [140] "add_13_intense"
# [141] "add_21_intense"
# [142] "add_22_intense"
# [143] "del_20_intense"
# [144] "del_3_intense"
# [145] "del_5_intense"
# [146] "del_7_intense"
# [147] "del_9_intense"
# [148] "del_12_intense"
# [149] "del_16_intense"
# [150] "del_17_intense"
# [151] "del_18_intense"
# [152] "minusy_intense"
# [153] "complex_intense"
# [154] "others_transloc_intense"
# [155] "intense"
# [1] "BGKAENJKLBHFJNKE"
#   [1] "eln_2017_adverse"
#   [2] "eln_2017_favorable"
#   [3] "eln_2017_intermediate"
#   [4] "eln_2017_adverse_intense"
#   [5] "eln_2017_favorable_intense"
#   [6] "eln_2017_intermediate_intense"
#   [7] "full_component_t_15_17"
#   [8] "full_component_inv_16"
#   [9] "full_component_t_8_21"
#  [10] "full_component_t_8_21_ITD"
#  [11] "full_component_t_11"
#  [12] "full_component_t_6_9"
#  [13] "full_component_t_6_9_ITD"
#  [14] "full_component_inv_3"
# ...
# [39] "KRAS_intense"
# [40] "MLL_intense"
# [41] "MYC_intense"
# [42] "NF1_intense"
# [43] "NRAS_p.G12_13_intense"
# [44] "NRAS_p.Q61_62_intense"
# [45] "PHF6_intense"
# [46] "PTPN11_intense"
# [47] "RAD21_intense"
# [48] "RUNX1_intense"
# [49] "SF3B1_intense"
# [50] "SMC1A_intense"
# [51] "SMC3_intense"
# [52] "SRSF2_intense"
# [53] "STAG2_intense"
# [54] "TET2_intense"
# [55] "TP53_intense"
# [56] "U2AF1_p.S34_intense"
# [57] "WT1_intense"
# [58] "add_8_intense"
# [59] "add_11_intense"
# [60] "add_13_intense"
# [61] "add_21_intense"
# [62] "add_22_intense"
# [63] "del_20_intense"
# [64] "del_3_intense"
# [65] "del_5_intense"
# [66] "del_7_intense"
# [67] "del_9_intense"
# [68] "del_12_intense"
# [69] "del_16_intense"
# [70] "del_17_intense"
# [71] "del_18_intense"
# [72] "minusy_intense"
# [73] "complex_intense"
# [74] "others_transloc_intense"
# [75] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "eln_2017_adverse_intense"
#  [2] "eln_2017_favorable_intense"
#  [3] "eln_2017_intermediate_intense"
#  [4] "full_component_t_15_17_intense"
#  [5] "full_component_inv_16_intense"
#  [6] "full_component_t_8_21_intense"
#  [7] "full_component_t_8_21_ITD_intense"
#  [8] "full_component_t_11_intense"
#  [9] "full_component_t_6_9_intense"
# [10] "full_component_t_6_9_ITD_intense"
# [11] "full_component_inv_3_intense"
# [12] "full_component_additions_intense"
# [13] "full_component_TP53_complex_intense"
# [14] "full_component_NPM1_intense"
# [15] "full_component_NPM1_ITD_intense"
# [16] "full_component_CEBPA_bi_intense"
# [17] "full_component_CEBPA_bi_ITD_intense"
# [18] "full_component_DNMT3A_IDH1_2_intense"
# [19] "full_component_DNMT3A_IDH1_2_ITD_intense"
# [20] "full_component_WT1_intense"
# [21] "full_component_WT1_ITD_intense"
# [22] "full_component_chr_splicing_multiple_intense"
# [23] "full_component_chr_splicing_1_intense"
# [24] "full_component_not_assigned_intense"
# [25] "full_component_not_assigned_ITD_intense"
# [26] "full_component_no_events_intense"
# [27] "overlap_intense"
# [28] "ASXL1_intense"
# [29] "BCOR_intense"
# [30] "CBL_intense"
# [31] "CEBPA_mono_intense"
# [32] "DNMT3A_intense"
# [33] "EZH2_intense"
# [34] "ITD_intense"
# [35] "FLT3_TKD_intense"
# [36] "FLT3_other_intense"
# [37] "GATA2_intense"
# [38] "IDH1_intense"
# [39] "IDH2_p.R140_intense"
# [40] "IDH2_p.R172_intense"
# [41] "KIT_intense"
# [42] "KRAS_intense"
# [43] "MLL_intense"
# [44] "MYC_intense"
# [45] "NF1_intense"
# [46] "NRAS_p.G12_13_intense"
# [47] "NRAS_p.Q61_62_intense"
# [48] "PHF6_intense"
# [49] "PTPN11_intense"
# [50] "RAD21_intense"
# [51] "RUNX1_intense"
# [52] "SF3B1_intense"
# [53] "SMC1A_intense"
# [54] "SMC3_intense"
# [55] "SRSF2_intense"
# [56] "STAG2_intense"
# [57] "TET2_intense"
# [58] "TP53_intense"
# [59] "U2AF1_p.S34_intense"
# [60] "WT1_intense"
# [61] "add_8_intense"
# [62] "add_11_intense"
# [63] "add_13_intense"
# [64] "add_21_intense"
# [65] "add_22_intense"
# [66] "del_20_intense"
# [67] "del_3_intense"
# [68] "del_5_intense"
# [69] "del_7_intense"
# [70] "del_9_intense"
# [71] "del_12_intense"
# [72] "del_16_intense"
# [73] "del_17_intense"
# [74] "del_18_intense"
# [75] "minusy_intense"
# [76] "complex_intense"
# [77] "others_transloc_intense"
# [78] "ahd"
# [79] "perf_status"
# [80] "bm_blasts"
# [81] "secondary"
# [82] "wbc"
# [83] "hb"
# [84] "plt"
# [85] "gender"
# [86] "age"
# [87] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "full_component_t_15_17_intense"
#  [2] "full_component_inv_16_intense"
#  [3] "full_component_t_8_21_intense"
#  [4] "full_component_t_8_21_ITD_intense"
#  [5] "full_component_t_11_intense"
#  [6] "full_component_t_6_9_intense"
#  [7] "full_component_t_6_9_ITD_intense"
#  [8] "full_component_inv_3_intense"
#  [9] "full_component_additions_intense"
# [10] "full_component_TP53_complex_intense"
# [11] "full_component_NPM1_intense"
# [12] "full_component_NPM1_ITD_intense"
# [13] "full_component_CEBPA_bi_intense"
# [14] "full_component_CEBPA_bi_ITD_intense"
# [15] "full_component_DNMT3A_IDH1_2_intense"
# [16] "full_component_DNMT3A_IDH1_2_ITD_intense"
# [17] "full_component_WT1_intense"
# [18] "full_component_WT1_ITD_intense"
# [19] "full_component_chr_splicing_multiple_intense"
# [20] "full_component_chr_splicing_1_intense"
# [21] "full_component_not_assigned_intense"
# [22] "full_component_not_assigned_ITD_intense"
# [23] "full_component_no_events_intense"
# [24] "overlap_intense"
# [25] "ASXL1_intense"
# [26] "BCOR_intense"
# [27] "CBL_intense"
# [28] "CEBPA_mono_intense"
# [29] "DNMT3A_intense"
# [30] "EZH2_intense"
# [31] "ITD_intense"
# [32] "FLT3_TKD_intense"
# [33] "FLT3_other_intense"
# [34] "GATA2_intense"
# [35] "IDH1_intense"
# [36] "IDH2_p.R140_intense"
# [37] "IDH2_p.R172_intense"
# [38] "KIT_intense"
# [39] "KRAS_intense"
# [40] "MLL_intense"
# [41] "MYC_intense"
# [42] "NF1_intense"
# [43] "NRAS_p.G12_13_intense"
# [44] "NRAS_p.Q61_62_intense"
# [45] "PHF6_intense"
# [46] "PTPN11_intense"
# [47] "RAD21_intense"
# [48] "RUNX1_intense"
# [49] "SF3B1_intense"
# [50] "SMC1A_intense"
# [51] "SMC3_intense"
# [52] "SRSF2_intense"
# [53] "STAG2_intense"
# [54] "TET2_intense"
# [55] "TP53_intense"
# [56] "U2AF1_p.S34_intense"
# [57] "WT1_intense"
# [58] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "full_component_t_15_17_intense"
#  [2] "full_component_inv_16_intense"
#  [3] "full_component_t_8_21_intense"
#  [4] "full_component_t_8_21_ITD_intense"
#  [5] "full_component_t_11_intense"
#  [6] "full_component_t_6_9_intense"
#  [7] "full_component_t_6_9_ITD_intense"
#  [8] "full_component_inv_3_intense"
#  [9] "full_component_additions_intense"
# [10] "full_component_TP53_complex_intense"
# [11] "full_component_NPM1_intense"
# [12] "full_component_NPM1_ITD_intense"
# [13] "full_component_CEBPA_bi_intense"
# [14] "full_component_CEBPA_bi_ITD_intense"
# [15] "full_component_DNMT3A_IDH1_2_intense"
# [16] "full_component_DNMT3A_IDH1_2_ITD_intense"
# [17] "full_component_WT1_intense"
# [18] "full_component_WT1_ITD_intense"
# [19] "full_component_chr_splicing_multiple_intense"
# [20] "full_component_chr_splicing_1_intense"
# [21] "full_component_not_assigned_intense"
# [22] "full_component_not_assigned_ITD_intense"
# [23] "full_component_no_events_intense"
# [24] "overlap_intense"
# [25] "add_8_intense"
# [26] "add_11_intense"
# [27] "add_13_intense"
# [28] "add_21_intense"
# [29] "add_22_intense"
# [30] "del_20_intense"
# [31] "del_3_intense"
# [32] "del_5_intense"
# [33] "del_7_intense"
# [34] "del_9_intense"
# [35] "del_12_intense"
# [36] "del_16_intense"
# [37] "del_17_intense"
# [38] "del_18_intense"
# [39] "minusy_intense"
# [40] "complex_intense"
# [41] "others_transloc_intense"
# [42] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "eln_2017_adverse_intense"      "eln_2017_favorable_intense"
#  [3] "eln_2017_intermediate_intense" "ASXL1_intense"
#  [5] "BCOR_intense"                  "CBL_intense"
#  [7] "CEBPA_bi_intense"              "CEBPA_mono_intense"
#  [9] "DNMT3A_intense"                "EZH2_intense"
# [11] "ITD_intense"                   "FLT3_TKD_intense"
# [13] "FLT3_other_intense"            "GATA2_intense"
# [15] "IDH1_intense"                  "IDH2_p.R140_intense"
# [17] "IDH2_p.R172_intense"           "KIT_intense"
# [19] "KRAS_intense"                  "MLL_intense"
# [21] "MYC_intense"                   "NF1_intense"
# [23] "NPM1_intense"                  "NRAS_p.G12_13_intense"
# [25] "NRAS_p.Q61_62_intense"         "PHF6_intense"
# [27] "PTPN11_intense"                "RAD21_intense"
# [29] "RUNX1_intense"                 "SF3B1_intense"
# [31] "SMC1A_intense"                 "SMC3_intense"
# [33] "SRSF2_intense"                 "STAG2_intense"
# [35] "TET2_intense"                  "TP53_intense"
# [37] "U2AF1_p.S34_intense"           "WT1_intense"
# [39] "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "eln_2017_adverse_intense"      "eln_2017_favorable_intense"
#  [3] "eln_2017_intermediate_intense" "add_8_intense"
#  [5] "add_11_intense"                "add_13_intense"
#  [7] "add_21_intense"                "add_22_intense"
#  [9] "del_20_intense"                "del_3_intense"
# [11] "del_5_intense"                 "del_7_intense"
# [13] "del_9_intense"                 "del_12_intense"
# [15] "del_16_intense"                "del_17_intense"
# [17] "del_18_intense"                "minusy_intense"
# [19] "t_v_11_intense"                "t_8_21_intense"
# [21] "complex_intense"               "others_transloc_intense"
# [23] "inv_16_intense"                "intense"
# [1] "BGKAENJKLBHFJNKE"
#  [1] "eln_2017_adverse_intense"      "eln_2017_favorable_intense"
#  [3] "eln_2017_intermediate_intense" "ASXL1_intense"
#  [5] "BCOR_intense"                  "CBL_intense"
#  [7] "CEBPA_bi_intense"              "CEBPA_mono_intense"
#  [9] "DNMT3A_intense"                "EZH2_intense"
# [11] "ITD_intense"                   "FLT3_TKD_intense"
# [13] "FLT3_other_intense"            "GATA2_intense"
# [15] "IDH1_intense"                  "IDH2_p.R140_intense"
# [17] "IDH2_p.R172_intense"           "KIT_intense"
# [19] "KRAS_intense"                  "MLL_intense"
# [21] "MYC_intense"                   "NF1_intense"
# [23] "NPM1_intense"                  "NRAS_p.G12_13_intense"
# [25] "NRAS_p.Q61_62_intense"         "PHF6_intense"
# [27] "PTPN11_intense"                "RAD21_intense"
# [29] "RUNX1_intense"                 "SF3B1_intense"
# [31] "SMC1A_intense"                 "SMC3_intense"
# [33] "SRSF2_intense"                 "STAG2_intense"
# [35] "TET2_intense"                  "TP53_intense"
# [37] "U2AF1_p.S34_intense"           "WT1_intense"
# [39] "add_8_intense"                 "add_11_intense"
# [41] "add_13_intense"                "add_21_intense"
# [43] "add_22_intense"                "del_20_intense"
# [45] "del_3_intense"                 "del_5_intense"
# [47] "del_7_intense"                 "del_9_intense"
# [49] "del_12_intense"                "del_16_intense"
# [51] "del_17_intense"                "del_18_intense"
# [53] "minusy_intense"                "t_v_11_intense"
# [55] "t_8_21_intense"                "complex_intense"
# [57] "others_transloc_intense"       "inv_16_intense"
# [59] "intense"
