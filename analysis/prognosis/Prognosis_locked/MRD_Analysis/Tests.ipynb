# %%
l <- read.table("aml17MFCmrd C1 C2.xlsx",sep=' ')
# Out:
# Warning message in read.table("aml17MFCmrd C1 C2.xlsx", sep = " "):
# “line 1 appears to contain embedded nulls”Warning message in read.table("aml17MFCmrd C1 C2.xlsx", sep = " "):
# “line 2 appears to contain embedded nulls”Warning message in read.table("aml17MFCmrd C1 C2.xlsx", sep = " "):
# “line 3 appears to contain embedded nulls”Warning message in read.table("aml17MFCmrd C1 C2.xlsx", sep = " "):
# “line 4 appears to contain embedded nulls”Warning message in read.table("aml17MFCmrd C1 C2.xlsx", sep = " "):
# “line 5 appears to contain embedded nulls”Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# “embedded nul(s) found in input”

# %%
head(l)
# Out:
# Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# “input string 1 is invalid in this locale”Warning message in FUN(X[[i]], ...):
# ...
