# %%
df <- rbind(read.table("SVM_tmp.csv",header=T,sep=","),read.table("SVM_tmp1.csv",header=T,sep=","))
df$Ratio <- df$ref_CI/df$permuted_CI
#df[order(df$Ratio,decreasing=T),]
library(ggplot2)
source("../../../src/tools.R")
set_notebook_plot_size(50,10)
ggplot(df,aes(x=reorder(feature,-Ratio,median),y=Ratio)) + geom_boxplot(aes(fill = reorder(feature,-Ratio,median)), notch=F)+theme(plot.title = element_text( size=45, face="bold.italic",hjust=0.5),legend.position="none",axis.text.x = element_text(angle = 90, hjust = 0.8,vjust=0.8,size=18),axis.text.y=element_text(size=28),axis.title.y = element_text(size = 20),axis.title.x = element_text(size = 20))+xlab("Selected Features") +
ggtitle("Feature Importance Reshuffling (Ratio of reference C-I over reshuffle C-I 100 times by feature)")
# Out:
# plot without title

# %%
df1 <- df[df$model=="all_features",]
ggplot(df1,aes(x=reorder(feature,-Ratio,median),y=Ratio)) + geom_boxplot(aes(fill = reorder(feature,-Ratio,median)), notch=F)+theme(plot.title = element_text( size=45, face="bold.italic",hjust=0.5),legend.position="none",axis.text.x = element_text(angle = 90, hjust = 0.8,vjust=0.8,size=18),axis.text.y=element_text(size=28),axis.title.y = element_text(size = 20),axis.title.x = element_text(size = 20))+xlab("Selected Features") +
ggtitle("Feature Importance Reshuffling (Ratio of reference C-I over reshuffle C-I 100 times by feature)")
# Out:
# plot without title

# %%
df2 <- df[df$model=="eln_comp",]
ggplot(df2,aes(x=reorder(feature,-Ratio,median),y=Ratio)) + geom_boxplot(aes(fill = reorder(feature,-Ratio,median)), notch=F)+theme(plot.title = element_text( size=45, face="bold.italic",hjust=0.5),legend.position="none",axis.text.x = element_text(angle = 90, hjust = 0.8,vjust=0.8,size=18),axis.text.y=element_text(size=28),axis.title.y = element_text(size = 20),axis.title.x = element_text(size = 20))+xlab("Selected Features") +
ggtitle("Feature Importance Reshuffling (Ratio of reference C-I over reshuffle C-I 100 times by feature)")
# Out:
# plot without title

# %%
table(df$model)
# Out:
#                        all_features            all_features_without_age
#                                   0                                   0
#                           clin_comp                      clin_cyto_comp
#                                   0                                   0
#                      clin_demo_comp          clin_demo_comp_without_age
#                                   0                                   0
#             clin_demo_cyto_gen_comp                       clin_gen_comp
#                                   0                                   0
#                                comp                           cyto_comp
#                                   0                                   0
#                       cyto_gen_comp                       eln_clin_comp
#                                   0                                   0
#                  eln_clin_demo_comp                       eln_cyto_comp
#                                   0                                   0
#                   eln_cyto_gen_comp                        eln_gen_comp
#                                   0                                   0
#                            gen_comp                           clin_cyto
#                                   0                                   0
#                           clin_demo                      clin_demo_cyto
#                                   0                                   0
#                  clin_demo_cyto_gen clin_demo_cyto_gen_comp_without_age
#                                   0                                   0
#      clin_demo_cyto_gen_without_age          clin_demo_cyto_without_age
#                                   0                                   0
#                       clin_demo_gen           clin_demo_gen_without_age
#                                   0                                   0
#               clin_demo_without_age                            clin_gen
#                                   0                                   0
#                                cyto                            cyto_gen
#                                   0                                   0
#                           demo_cyto               demo_cyto_without_age
#                                   0                                   0
#                            demo_gen                demo_gen_without_age
#                                   0                                   0
#                             eln_age                            eln_clin
#                                   0                                   0
#                       eln_clin_demo      eln_clin_demo_comp_without_age
#                                   0                                   0
#                  eln_clin_demo_cyto              eln_clin_demo_cyto_gen
#                                   0                                   0
#  eln_clin_demo_cyto_gen_without_age      eln_clin_demo_cyto_without_age
#                                   0                                   0
#                   eln_clin_demo_gen       eln_clin_demo_gen_without_age
#                                   0                                   0
#           eln_clin_demo_without_age                        eln_clin_gen
#                                   0                                   0
#                            eln_comp                            eln_cyto
#                                   0                                   0
#                        eln_cyto_gen                        eln_demo_gen
#                                   0                                   0
#            eln_demo_gen_without_age                             eln_gen
#                                   0                                   0
#                                 gen                             gen_age
#                                   0                                   0
